# %% [markdown]
# LECTURE 2 PRACTICE

# %% [markdown]
# (Time & Space Complexity)

# %% [markdown]
# 🟢 SECTION A: BASIC COMPLEXITY
# Q1. What does Big-O represent?
#
# Answer:
# Worst-case growth rate of an algorithm.
#
# Q2. What does n represent in complexity?
#
# Answer:
# Size of input.
#
# Q3. Is Big-O machine dependent?
#
# Answer:
# No.
#
# Q4. What is O(1)?
#
# Answer:
# Constant time.
#
# Q5. What is O(n)?
#
# Answer:
# Linear time.
#
# 🟡 SECTION B: CODE ANALYSIS
# Q6. Time complexity?
# for i in range(n):
#     print(i)
#
#
# Answer:
# O(n)
#
# Q7.
# for i in range(10):
#     print(i)
#
#
# Answer:
# O(1)
#
# Q8.
# for i in range(n):
#     for j in range(n):
#         print(i, j)
#
#
# Answer:
# O(n²)
#
# Q9.
# while n > 1:
#     n = n // 2
#
#
# Answer:
# O(log n)
#
# Q10.
# nums.sort()
#
#
# Answer:
# O(n log n)
#
# 🟡 SECTION C: SPACE COMPLEXITY
# Q11. Space complexity?
# def sum(nums):
#     s = 0
#     for x in nums:
#         s += x
#     return s
#
#
# Answer:
# O(1)
#
# Q12.
# def copy(nums):
#     res = []
#     for x in nums:
#         res.append(x)
#     return res
#
#
# Answer:
# O(n)
#
# Q13. Is input array counted in space complexity?
#
# Answer:
# No.
#
# Q14. Space complexity of recursion depth n?
#
# Answer:
# O(n)
#
# Q15. Space complexity of binary search recursion?
#
# Answer:
# O(log n)
#
# 🔴 SECTION D: INTERVIEW-LEVEL THINKING
# Q16. Why is binary search O(log n)?
#
# Answer:
# Search space halves each step.
#
# Q17. Why is nested loop O(n²)?
#
# Answer:
# Each element is processed n times.
#
# Q18. Why do we drop constants in Big-O?
#
# Answer:
# They don’t affect growth rate.
#
# Q19. Which is better: O(n) or O(log n)?
#
# Answer:
# O(log n)
#
# Q20. Which is worse: O(n²) or O(2ⁿ)?
#
# Answer:
# O(2ⁿ)

# %% [markdown]
# Q21–25 (Rapid Fire)
#
# | Question            | Answer     |
# | ------------------- | ---------- |
# | Hash lookup         | O(1)       |
# | Sorting lower bound | O(n log n) |
# | Three loops         | O(n³)      |
# | Fibonacci recursion | O(2ⁿ)      |
# | Permutations        | O(n!)      |
